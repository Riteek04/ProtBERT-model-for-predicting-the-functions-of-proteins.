# %% [markdown]
# # ProBERT: Protein Subcellular Localization and Function Prediction
# This notebook implements ProBERT for protein sequence analysis. Prepared for GitHub sharing.
#
# _Note: Please ensure necessary files and models are available when running locally or in Colab._
